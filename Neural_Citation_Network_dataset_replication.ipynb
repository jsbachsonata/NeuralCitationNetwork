# %% [markdown]
# <a href="https://colab.research.google.com/github/jsbachsonata/NeuralCitationNetwork/blob/master/Neural_Citation_Network_dataset_replication.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# download data from github
# %%bash
!(stat -t /usr/local/lib/*/dist-packages/google/colab > /dev/null 2>&1) && exit
rm -rf NeuralCitationNetwork/
git clone http://jsbachsonata:TopCoderKitty88@github.com/jsbachsonata/NeuralCitationNetwork.git
# Out:
# Cloning into 'NeuralCitationNetwork'...
# ...

# %%
import pickle as cPickle

# %%
df = cPickle.load(open('../content/drive/My Drive/title_context_df.pkl', 'rb'))

# %%
len(df)
# Out:
# 27428

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
from __future__ import unicode_literals
import argparse
import easydict
parser = argparse.ArgumentParser()

parser.add_argument('-g', '--gpu', help='set gpu device number 0-3', type=str)
parser.add_argument('-r', '--restore', help='optional, only if restoring', type=str,
                    default=None)
parser.add_argument('-i', '--input', help='Data input filename', type=str)

import os
args = easydict.EasyDict({
    "gpu": "0",
    "restore": "optional",
    "input": "../content/drive/My Drive/seq_data.h5py"
})
# os.environ["CUDA_VISIBLE_DEVICES"] = args.gpu

import sys
import threading
import pickle as cPickle
from logging.config import dictConfig
import logging
import json


import tensorflow as tf
import numpy as np

sys.path.append('/content/NeuralCitationNetwork/')
from rbase.citerec import PAD_TOKEN, GO_TOKEN, END_TOKEN, CitationContextDataset
# from rbase.seq2seq import DeepCNNtoRNN

# %%
filename = args.input

# %%
dataset = CitationContextDataset(filename)

# %%
author_vocab = dataset.getAuthorVocab()

# %%
author_vocab = author_vocab._mapping

# %%
dataset.addAuthorVocab(author_vocab)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-16-5eb7a5b06823> in <module>()
# ----> 1 dataset.addAuthorVocab(author_vocab)
#
# /content/NeuralCitationNetwork/rbase/citerec.py in addAuthorVocab(self, vocab_obj)
#     192
#     193     def addAuthorVocab(self, vocab_obj):
# --> 194         self.addPickle('author', 'data', vocab_obj)
#     195
#     196     def getAuthorVocab(self):
#
# /content/NeuralCitationNetwork/rbase/citerec.py in addPickle(self, group, key, obj)
#     118         group, key = self._checkKeys(group, key)
#     119         self._checkDataset(group)
# --> 120         self._file[group].attrs[key] = np.void(b"%s" % cPickle.dumps(obj, cPickle.HIGHEST_PROTOCOL))
#     121
#     122     def addArray(self, key, data):
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ...

# %%
dataset.getContext("0")
# Out:
# {'citationid': '514445',
#  'citing_authors': [3605, 11211, 12668, 26309, 32810],
#  'citing_cluster': 5501374,
#  'cluster': 131597,
#  'cluster_authors': [3480, 15246, 21164],
#  'context': [5513,
#   13,
#   32,
#   827,
#   5,
#   1027,
#   528,
#   90,
#   133,
#   3,
#   2,
#   208,
#   4,
#   2,
#   0,
#   184,
#   7,
#   2268,
#   4076,
#   3,
#   7,
#   1140,
#   2,
#   1254,
#   249,
#   16,
#   2,
#   2183,
#   132,
#   4],
#  'title': [5, 456, 80, 166, 2, 1395, 314, 1487, 4, 5, 61, 13],
#  'year': 1900}

# %%
encoder_vocab = dataset.getEncoderVocab()._mapping
decoder_vocab = dataset.getDecoderVocab()._mapping

# %%
dataset.getPaperClusters()
# Out:
# {2097152: {'authors': ['z liu', 'm cohen'],
#   'authors_raw': ['Z Liu', 'M F Cohen'],
#   'authors_seq': [62, 233],
#   'test': False,
#   'title': 'an efficient symbolic interface to constraint base animation system',
#   'title_seq': [15, 36, 546, 157, 10, 71, 12, 1002, 11],
#   'train': False,
#   'valid': False,
#   'year': 1994},
#  1747627: {'authors': ['f vella', 'm verbeek'],
#   'authors_raw': ['Francis Vella', 'Marno Verbeek'],
#   'authors_seq': [58539, 29915],
#   'test': False,
#   'title': 'estimate and interpret model with endogenous treatment effect',
#   'title_seq': [311, 4, 2469, 13, 9, 2561, 1242, 110],
#   'train': False,
#   'valid': False,
#   'year': 1993},
#  4194309: {'authors': ['a a', 't nabeth'],
#   'authors_raw': ['A A', 'T Nabeth'],
#   'authors_seq': [1475, 27185],
#   'test': False,
#   'title': 'the l2c project learn to collaborate through advanced smallworld simulation',
#   'title_seq': [6, 20002, 442, 39, 10, 6520, 138, 1036, 20003, 81],
# ...

# %%
# create pickles for encoder, decoder and author vocab dictionaries
# DO NOT USE getAuthorVocab, getEncoderVocab and getDecoderVocab from CitationContextDataset
with open('../content/drive/My Drive/NCN_author_vocab.pickle', 'wb') as f:
    cPickle.dump(author_vocab, f)

# %%
with open('../content/drive/My Drive/NCN_encoder_vocab.pickle', 'wb') as f:
    cPickle.dump(encoder_vocab, f)

# %%
with open('../content/drive/My Drive/NCN_decoder_title_vocab.pickle', 'wb') as f:
    cPickle.dump(decoder_vocab, f)
